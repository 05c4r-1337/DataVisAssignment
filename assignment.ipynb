# %% [markdown]
# ---
# # Assignment: Data Visualization using a Visualization Library
# ---
#
# #### In this assignment, you will conduct an exploratory data analysis with visualizations on an Olympic Athletes dataset.
#
# How to use this Notebook:
# -  Firstly, make sure you have completed [1. Setup](#1-setup).
# -  Secondly, complete [Task 1: Preprocessing](#task-1-preprocessing).
# -  Then, you can complete [Task 2: Summary Statistics](#task-2-summary-statistics) to [Task 6: Map Visualizations](#task-6-map-visualizations) in any order.
# -  Lastly, complete [Task 7: Submission](#task-7-submission).
#
# The various tasks contain Notebook cells with `TODO`s.
# - You need to complete all `TODO`s.
#
# Assignment files and folders.
# - The file `assignment.ipynb` is this Notebook.
# - The folder `data` contains:
#   - 4 `.csv` files with the data for this assignment.
#   - A `verify.pkl` file you can use to verify your solution in [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering).
# - The folder `figures` contains:
#   - 19 `.png` figures you can use to verify your solutions to the visualization tasks in [Task 3: Distribution Visualizations](#task-3-distribution-visualizations) to [Task 6: Map Visualizations](#task-6-map-visualizations).
#   - Your visualizations need to be similar, but not identical to, the sample visualizations.
#   - The sample visualizations are provided as an aid so that you know what to aim for.
#
# This Notebook contains:
#
# - [1. Setup](#1-setup)
#   - [Python Virtual Environment](#python-virtual-environment)
#   - [Python and Pip Version](#python-and-pip-version)
#   - [Python Packages](#python-packages)
#   - [Python Modules](#python-modules)
#   - [Pandas Configuration](#pandas-configuration)
#   - [Dataset](#dataset)
# - [Task 1: Preprocessing](#task-1-preprocessing)
#   - [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering)
#   - [Task 1.2 Feature Measurement Scales](#task-12-feature-measurement-scales)
# - [Task 2: Summary Statistics](#task-2-summary-statistics)
#   - [Task 2.1 Missing Values](#task-21-missing-values)
#   - [Task 2.2 Unique Values](#task-22-unique-values)
#   - [Task 2.3 Value Counts](#task-23-value-counts)
#   - [Task 2.4 Central Tendency and Spread](#task-24-central-tendency-and-spread)
#   - [Task 2.5 Outliers](#task-25-outliers)
# - [Task 3: Distribution Visualizations](#task-3-distribution-visualizations)
#   - [Task 3.1 Visualize the Distribution of Male and Female Athletes](#task-31-visualize-the-distribution-of-male-and-female-athletes)
#   - [Task 3.2 Visualize the Distribution of Athletes' Age](#task-32-visualize-the-distribution-of-athletes-age)
#   - [Task 3.3 Visualize the Distribution of Athletes' Height](#task-33-visualize-the-distribution-of-athletes-height)
#   - [Task 3.4 Visualize the Distribution of Athletes' Weight](#task-34-visualize-the-distribution-of-athletes-weight)
#   - [Task 3.5 Visualize the Distribution in Height of Male and Female Athletes](#task-35-visualize-the-distribution-in-height-of-male-and-female-athletes)
#   - [Task 3.6 Visualize the Height per Type of Medal for Male and Female Athletes](#task-36-visualize-the-height-per-type-of-medal-for-male-and-female-athletes)
#   - [Task 3.7 Visualize the Weight per Type of Medal for Male and Female Athletes](#task-37-visualize-the-weight-per-type-of-medal-for-male-and-female-athletes)
#   - [Task 3.8 Visualize Height per Type of Medal for Male and Female Athletes Faceted by Season](#task-38-visualize-height-per-type-of-medal-for-male-and-female-athletes-faceted-by-season)
#   - [Task 3.9 Visualize the Average Age per Sport](#task-39-visualize-the-average-age-per-sport)
#   - [Task 3.10 Visualize the Top 10 Countries (Regions) with Most Total Medals](#task-310-visualize-the-top-10-countries-regions-with-most-total-medals)
#   - [Task 3.11 Visualize the Top 10 Atheletes by Total Awarded Medals](#task-311-visualize-the-top-10-atheletes-by-total-awarded-medals)
#   - [Task 3.12 Visualize the Age, Height and Weight Distribution per Type of Medal](#task-312-visualize-the-age-height-and-weight-distribution-per-type-of-medal)
#   - [Task 3.13 Interpret a Box Plot's Visual Elements](#task-313-interpret-a-box-plots-visual-elements)
# - [Task 4: Trend Visualizations](#task-4-trend-visualizations)
#   - [Task 4.1 Visualize Body Mass Index (BMI) Over Time](#task-41-visualize-body-mass-index-bmi-over-time)
#   - [Task 4.2 Visualize Gender (Sex) Participation Over Time](#task-42-visualize-gender-sex-participation-over-time)
# - [Task 5: Correlation Visualizations](#task-5-correlation-visualizations)
#   - [Task 5.1 Visualize Pairwise Correlations of Athlete's Age, Height and Weight per Sex with a `pairplot`](#task-51-visualize-pairwise-correlations-of-athletes-age-height-and-weight-per-sex-with-a-pairplot)
#   - [Task 5.2 Visualize Pairwise Correlations of the Numeric Features with a `heatmap`](#task-52-visualize-pairwise-correlations-of-the-numeric-features-with-a-heatmap)
#   - [Task 5.3 Visualize Atheltes' Weight versus Height per Sex with a `lineplot`](#task-53-visualize-atheltes-weight-versus-height-per-sex-with-a-lineplot)
#   - [Task 5.4 Visualize Atheltes' Weight versus Height per Sex with a `scatterplot`](#task-54-visualize-atheltes-weight-versus-height-per-sex-with-a-scatterplot)
# - [Task 6: Map Visualizations](#task-6-map-visualizations)
#   - [Task 6.1 Visualize Number of Medals on a Map for the Nordic Countries](#task-61-visualize-number-of-medals-on-a-map-for-the-nordic-countries)
# - [Task 7: Submission](#task-7-submission)
#   - [Task 7.1 Verify the Integrity of your Notebook](#task-71-verify-the-integrity-of-your-notebook)
#   - [Task 7.2 Submit the Assignment](#task-72-submit-the-assignment)

# %% [markdown]
# ---
# # Setup
# ---

# %% [markdown]
# ## Python Virtual Environment
#
# - Make sure you have downloaded the GitHub repository (which contains the assignment).
#   - **Alternative 1**: You can use the same `git clone` as in the workshops.
#
#     ```bash
#     git clone https://github.com/paga-hb/C1VI1B_2025.git dataviz
#     cd dataviz
#     ```
#
#   - **Alternative 2**: You can `git clone` the repository into another folder just for the assignment.
#
#     ```bash
#     git clone https://github.com/paga-hb/C1VI1B_2025.git dataviz_assignment
#     cd dataviz_assignment
#     ```
#
# - Make sure you have created a Python Virtual Environment as below.
#
#     ```bash
#     conda create -y -p ./.conda python=3.12
#     conda activate ./.conda
#     python -m pip install --upgrade pip
#     pip install ipykernel jupyter pylance numpy pandas matplotlib seaborn basemap pillow
#     # You can install more packages, but for this assignment you need (at least) the packages listed above
#     ```
#
# - Also make sure you have selected your Python Virtual Environment in your Notebook.
#   - In the top right of your Notebook, click `Select Kernel`.
#   - Choose your Python Virtual Environment.

# %% [markdown]
# ---
# ## Python and Pip Version
#
# Let's start by printing out the Python and Pip version you are using in your Python Virtual Environment.

# %%
# !python --version
# !pip --version
# Out:
# Python 3.12.11
# pip 25.2 from c:\Users\ajdin\Documents\DataVisAssignment\.conda\Lib\site-packages\pip (python 3.12)

# %% [markdown]
# ---
# ## Python Packages
#
# Let's also make sure the necessary Python packages are installed in our Python Virtual Environment.
# - I have included some default packages below (many of which might already be installed in your Python Virtual Environment).
# - If you use any other `pip` or `conda` packages, add them in the cell below.
#   - Use `%pip install <package>` for Pip packages.
#   - Use `%conda install <package>` for Conda packages.
#
#
# Note
# - When you install a `conda` package, you might have to restart your Jupyter Notebook kernel.
# - To restart your Jupyter Notebook kernel, click the `Restart` button at the top of the Notebook.

# %%
# %pip install ipykernel
# %pip install jupyter
# %pip install pylance
# %pip install numpy
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install basemap
# %pip install pillow
# Out:
# Requirement already satisfied: ipykernel in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (6.30.1)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (9.6.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.4.6)
# Requirement already satisfied: decorator in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-client>=8.0.0->ipykernel) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel) (311)
# Requirement already satisfied: six>=1.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: jupyter in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (1.1.1)
# Requirement already satisfied: notebook in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter) (7.4.7)
# Requirement already satisfied: jupyter-console in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter) (7.16.6)
# Requirement already satisfied: ipykernel in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter) (6.30.1)
# Requirement already satisfied: ipywidgets in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter) (8.1.7)
# Requirement already satisfied: jupyterlab in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter) (4.4.9)
# Requirement already satisfied: comm>=0.1.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (1.8.17)
# Requirement already satisfied: ipython>=7.23.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (9.6.0)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (1.6.0)
# Requirement already satisfied: packaging>=22 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (25.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (7.1.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipykernel->jupyter) (5.14.3)
# Requirement already satisfied: colorama in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.4.6)
# Requirement already satisfied: decorator in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipython>=7.23.1->ipykernel->jupyter) (0.6.3)
# Requirement already satisfied: wcwidth in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel->jupyter) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel->jupyter) (0.8.5)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-client>=8.0.0->ipykernel->jupyter) (2.9.0.post0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (4.4.0)
# Requirement already satisfied: pywin32>=300 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel->jupyter) (311)
# Requirement already satisfied: six>=1.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from python-dateutil>=2.8.2->jupyter-client>=8.0.0->ipykernel->jupyter) (1.17.0)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipywidgets->jupyter) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from ipywidgets->jupyter) (3.0.15)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (0.28.1)
# Requirement already satisfied: jinja2>=3.0.3 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (3.1.6)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (2.3.0)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (2.27.3)
# Requirement already satisfied: notebook-shim>=0.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (0.2.4)
# Requirement already satisfied: setuptools>=41.1.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab->jupyter) (78.1.1)
# Requirement already satisfied: anyio in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (4.11.0)
# Requirement already satisfied: certifi in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (2025.8.3)
# Requirement already satisfied: httpcore==1.* in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (1.0.9)
# Requirement already satisfied: idna in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab->jupyter) (3.10)
# Requirement already satisfied: h11>=0.16 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab->jupyter) (0.16.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.5.3)
# Requirement already satisfied: nbformat>=5.3.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (5.10.4)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.23.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.8.0)
# Requirement already satisfied: babel>=2.10 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.12.1)
# Requirement already satisfied: jsonschema>=4.18.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (4.25.1)
# Requirement already satisfied: requests>=2.31 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.32.5)
# Requirement already satisfied: sniffio>=1.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (1.3.1)
# Requirement already satisfied: typing_extensions>=4.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from anyio->httpx<1,>=0.25.0->jupyterlab->jupyter) (4.15.0)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (25.1.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jinja2>=3.0.3->jupyterlab->jupyter) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (0.27.1)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (6.0.3)
# Requirement already satisfied: rfc3339-validator in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (24.11.1)
# Requirement already satisfied: beautifulsoup4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbconvert->jupyter) (4.14.2)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbconvert->jupyter) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbconvert->jupyter) (0.10.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.21.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (3.4.3)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from requests>=2.31->jupyterlab-server<3,>=2.27.1->jupyterlab->jupyter) (2.5.0)
# Requirement already satisfied: lark>=1.2.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: cffi>=1.0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.23)
# Requirement already satisfied: soupsieve>1.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from beautifulsoup4->nbconvert->jupyter) (2.8)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->jupyterlab->jupyter) (2.9.0.20250822)
# Requirement already satisfied: executing>=1.2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from stack_data->ipython>=7.23.1->ipykernel->jupyter) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pylance in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (0.37.0)
# Requirement already satisfied: pyarrow>=14 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pylance) (21.0.0)
# Requirement already satisfied: numpy>=1.22 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pylance) (2.3.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: numpy in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (2.3.3)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pandas in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (2.3.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: matplotlib in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: numpy>=1.23 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (2.3.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: seaborn in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from seaborn) (2.3.3)
# Requirement already satisfied: pandas>=1.2 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from seaborn) (2.3.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from seaborn) (3.10.6)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: basemap in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (2.0.0)
# Requirement already satisfied: basemap_data<3.0,>=2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from basemap) (2.0.0)
# Requirement already satisfied: packaging<26.0,>=20.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from basemap) (25.0)
# Requirement already satisfied: numpy<2.4,>=2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from basemap) (2.3.3)
# Requirement already satisfied: matplotlib<3.11,>=3.4 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from basemap) (3.10.6)
# Requirement already satisfied: pyproj<3.8,>=3.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from basemap) (3.7.2)
# Requirement already satisfied: pyshp<2.4,>=2.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from basemap) (2.3.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (4.60.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (1.4.9)
# Requirement already satisfied: pillow>=8 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from matplotlib<3.11,>=3.4->basemap) (2.9.0.post0)
# Requirement already satisfied: certifi in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from pyproj<3.8,>=3.0->basemap) (2025.8.3)
# Requirement already satisfied: six>=1.5 in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (from python-dateutil>=2.7->matplotlib<3.11,>=3.4->basemap) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pillow in c:\users\ajdin\documents\datavisassignment\.conda\lib\site-packages (11.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ---
# ## Python Modules
#
# Let's import the necessary Python modules from the installed Python packages.
# - Numpy and Pandas are used for data mangling.
# - Matplotlib and/or Seaborn are used for visualizations.
# - If you need more imports, add them in the cell below.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap

# %% [markdown]
# ---
# ## Pandas Configuration
#
# Let's also configure Pandas to set the maximum number of rows and columns displayed from a `DataFrame` in a Jupyter Notebook cell.
# - Configuring the maximum number of rows.
#   - `pd.set_option('display.max_rows', None)` displays an unlimited number of rows (don't use this when working with large `DataFrame`s).
#   - `pd.set_option('display.max_rows', 25)` displays a maximum of `25` rows.
#   - `pd.reset_option('display.max_rows')` resets the number of rows to the default setting.
# - Configuring the maximum number of columns.
#   - `pd.set_option('display.max_columns', None)` displays an unlimited number of columns.
#   - `pd.set_option('display.max_columns', 25)` displays a maximum of `25` columns.
#   - `pd.reset_option('display.max_columns')` resets the number of columns to the default setting.

# %%
pd.reset_option('display.max_rows')        # show default number of rows
pd.set_option('display.max_columns', None) # show all columns

# %% [markdown]
# ---
# ## Dataset
#
# Let's load a pre-processed dataset containing information about Olymic athletes, events they competed in, etc., and inspect the features (columns).
# - `ID` is a unique identifier for an athlete.
# - `Name` is the athlete's name.
# - `Sex` is the athlete's sex, `M` for Male, or `F` for female.
# - `Age` is the athlete's age, for a specific `Year`.
# - `Height` is the athlete's height in centimeters (cm).
# - `Weight` is the athlete's weight in kilograms (kg).
# - `BMI` is the athlete's Body Mass Index, calculated as the weight (in kilograms) divided by the height (in meters): $BMI = \frac{Weight[kg]}{Height[m]^2}$
# - `Team` is the Olympic team the athlete is a member of.
# - `NOC` is the National Olympic Committee country code for the athlete.
# - `Region` is the region associated with the athlete's `NOC`.
# - `ISO3` is the ISO 3166-1 alpha-3 country code (a 3-letter code) for the athlete's country.
# - `Country` is the country name associated with the `ISO3` country code.
# - `Latitude` is the country's geographic latitude.
# - `Longitude` is the country's geographic longitude.
# - `Games` is the name of the Olymic games, e.g. `1992 Summer` for the 1992 summer games.
# - `Year` is the year of the Olymipc games.
# - `Season` is the season for the Olymipc games, i.e. `Summer` or `Winter`.
# - `City` is the city in which the Olymic games were held.
# - `Sport` is Olympic sport the athlete competed in.
# - `Event` is Olympic event the athlete competed in.
# - `Medal` is medal (Gold, Silver, Bronze) awarded to the athlete, if any.

# %%
df_verify = pd.read_pickle('data/verify.pkl')
print(f'Number of rows: {df_verify.shape[0]}')
print(f'Number of columns: {df_verify.shape[1]}')
df_verify.head() # head() displays the first 5 rows, head(10) displays the first 10 rows, etc.
# Out:
# Number of rows: 269731
# Number of columns: 21
#    ID                      Name Sex   Age  Height  Weight        BMI  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  24.691358
# 1   2                  A Lamusi   M  23.0   170.0    60.0  20.761246
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN        NaN
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN        NaN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  23.959094
#
#              Team  NOC       Region ISO3      Country  Latitude  Longitude  \
# 0           China  CHN        China  CHN        China      35.0     105.00
# 1           China  CHN        China  CHN        China      35.0     105.00
# 2         Denmark  DEN      Denmark  DNK      Denmark      56.0      10.00
# 3  Denmark/Sweden  DEN      Denmark  DNK      Denmark      56.0      10.00
# 4     Netherlands  NED  Netherlands  NLD  Netherlands      52.5       5.75
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN

# %% [markdown]
# Let's also print out the data types for the various features (columns).

# %%
df_verify.dtypes
# Out:
# ID             int64
# Name          object
# Sex           object
# Age          float64
# Height       float64
# Weight       float64
# BMI          float64
# Team          object
# NOC           object
# Region        object
# ISO3          object
# Country       object
# Latitude     float64
# Longitude    float64
# Games         object
# Year           int64
# Season        object
# City          object
# Sport         object
# Event         object
# Medal         object
# dtype: object

# %% [markdown]
# ---
# # Task 1: Preprocessing
# ---
#
# Use the [Numpy Guide](https://numpy.org/learn) and [Pandas Guide](https://pandas.pydata.org/docs/user_guide/index.html) to consult the documentation and view code examples, if needed.
#
# ## Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering
#
# Your first task is to load and preprocess the four `.csv` files in the `data` folder.
# - `athlete_events.csv` contains data about the athletes and events they competed in.
# - `geo.csv` contains ISO3 country codes with latitudes and longitides.
# - `noc_iso3.csv` contains mappings between NOC and ISO3 country codes.
# - `noc_regions.csv` contains NOC country codes with regions.
#
# When you are done, you should end up with **one** Pandas `DataFrame` (`df`) identical to the Pandas `DataFrame` (`df_verify`) above.
# - It should contain:
#   - The exact same column names (including large/small letters), in the same left-to-right order, and with the same data types.
#   - The same number of rows.
# - Once you have created your own DataFrame `df`, you can verify it by comparing it to the `df_verify` DataFrame (see cell below).
#
# Things to consider:
# - Remove all duplicates.
#   - This can be done using `df.drop_duplicates()` which considers complete rows with identical values as duplicates.
#   - Or, if you only want to consider a subset of the columns for each row as duplicates, you can use `df.drop_duplicates(subset='col')` where `col` is the column name.
#   - To print out the number of duplicates, you can use `df.duplicated().sum()`, or `df['col'].duplicated().sum()` for a specific column.
# - The `geo.csv` dataset contains unwanted characters in multiple columns, including columns with the wrong data types, and duplicate values in the `ISO3` column.
#   - When removing duplicates from this dataset, consider using `drop_duplicates(subset='ISO3')`.
# - When merging `DataFrames`, make sure you end up with the same number of rows as in the `athlete_events.csv` file (but with duplicates removed).
# - You will also have to compute the BMI column and add it to the `DataFrame` (see equation above).
# - Rename columns to match the column names in the `df_verify` DataFrame.
# - Reorder columns to match the column order in the `df_verify` DataFrame.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from mpl_toolkits.basemap import Basemap

df_verify = pd.read_pickle('data/verify.pkl')
pd.reset_option('display.max_rows')      
pd.set_option('display.max_columns', None)

df_athletes = pd.read_csv('data/athlete_events.csv')
df_geo = pd.read_csv('data/geo.csv')
df_noc_iso3 = pd.read_csv('data/noc_iso3.csv')
df_noc_regions = pd.read_csv('data/noc_regions.csv')


dfs = {'df_athletes': df_athletes,
       'df_geo': df_geo,
       'df_noc_iso3': df_noc_iso3,
       'df_noc_regions': df_noc_regions}


for name, df in dfs.items():
    print(f"\n=== {name} ===")
    print("Columns:", df.columns.tolist())
    print("Number of rows:", len(df))
    print("Data types:\n", df.dtypes)
    print("Missing values:\n", df.isna().sum())
    print("Sample data (first 100 rows):\n", df.head(100))
# Out:
# === df_athletes ===
# Columns: ['ID', 'Name', 'Sex', 'Age', 'Height', 'Weight', 'Team', 'NOC', 'Games', 'Year', 'Season', 'City', 'Sport', 'Event', 'Medal']
# Number of rows: 271116
# Data types:
#  ID          int64
# Name       object
# Sex        object
# Age       float64
# Height    float64
# Weight    float64
# Team       object
# NOC        object
# Games      object
# Year        int64
# Season     object
# City       object
# Sport      object
# Event      object
# Medal      object
# dtype: object
# Missing values:
#  ID             0
# Name           0
# Sex            0
# Age         9474
# Height     60171
# Weight     62875
# Team           0
# NOC            0
# Games          0
# Year           0
# Season         0
# City           0
# Sport          0
# Event          0
# Medal     231333
# dtype: int64
# Sample data (first 100 rows):
#      ID                                Name Sex   Age  Height  Weight  \
# 0    1                           A Dijiang   M  24.0   180.0    80.0
# 1    2                            A Lamusi   M  23.0   170.0    60.0
# 2    3                 Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3    4                Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4    5            Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ..  ..                                 ...  ..   ...     ...     ...
# 95  32                Olav Augunson Aarnes   M  23.0     NaN     NaN
# 96  33                 Mika Lauri Aarnikka   M  24.0   187.0    76.0
# 97  33                 Mika Lauri Aarnikka   M  28.0   187.0    76.0
# 98  34  Jamale (Djamel-) Aarrass (Ahrass-)   M  30.0   187.0    76.0
# 99  35              Dagfinn Sverre Aarskog   M  24.0   190.0    98.0
#
#               Team  NOC        Games  Year  Season       City          Sport  \
# 0            China  CHN  1992 Summer  1992  Summer  Barcelona     Basketball
# 1            China  CHN  2012 Summer  2012  Summer     London           Judo
# 2          Denmark  DEN  1920 Summer  1920  Summer  Antwerpen       Football
# 3   Denmark/Sweden  DEN  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4      Netherlands  NED  1988 Winter  1988  Winter    Calgary  Speed Skating
# ..             ...  ...          ...   ...     ...        ...            ...
# 95          Norway  NOR  1912 Summer  1912  Summer  Stockholm      Athletics
# 96         Finland  FIN  1992 Summer  1992  Summer  Barcelona        Sailing
# 97         Finland  FIN  1996 Summer  1996  Summer    Atlanta        Sailing
# 98          France  FRA  2012 Summer  2012  Summer     London      Athletics
# 99          Norway  NOR  1998 Winter  1998  Winter     Nagano      Bobsleigh
#
#                                Event Medal
# 0        Basketball Men's Basketball   NaN
# 1       Judo Men's Extra-Lightweight   NaN
# 2            Football Men's Football   NaN
# 3        Tug-Of-War Men's Tug-Of-War  Gold
# 4   Speed Skating Women's 500 metres   NaN
# ..                               ...   ...
# 95         Athletics Men's High Jump   NaN
# 96   Sailing Men's Two Person Dinghy   NaN
# 97   Sailing Men's Two Person Dinghy   NaN
# 98      Athletics Men's 1,500 metres   NaN
# 99              Bobsleigh Men's Four   NaN
#
# [100 rows x 15 columns]
#
# === df_geo ===
# Columns: ['Country', 'Alpha-2 code', 'Alpha-3 code', 'Numeric code', 'Latitude (average)', 'Longitude (average)']
# Number of rows: 262
# Data types:
#  Country                object
# Alpha-2 code           object
# Alpha-3 code           object
# Numeric code           object
# Latitude (average)     object
# Longitude (average)    object
# dtype: object
# Missing values:
#  Country                0
# Alpha-2 code           0
# Alpha-3 code           0
# Numeric code           0
# Latitude (average)     0
# Longitude (average)    0
# dtype: int64
# Sample data (first 100 rows):
#                                Country Alpha-2 code Alpha-3 code Numeric code  \
# 0                         Afghanistan         "AF"        "AFG"          "4"
# 1                       Åland Islands         "AX"        "ALA"        "248"
# 2                             Albania         "AL"        "ALB"          "8"
# 3                             Algeria         "DZ"        "DZA"         "12"
# 4                      American Samoa         "AS"        "ASM"         "16"
# ..                                ...          ...          ...          ...
# 95                      Guinea-Bissau         "GW"        "GNB"        "624"
# 96                             Guinea         "GN"        "GIN"        "324"
# 97                             Guyana         "GY"        "GUY"        "328"
# 98                              Haiti         "HT"        "HTI"        "332"
# 99  Heard Island and McDonald Islands         "HM"        "HMD"        "334"
#
#    Latitude (average) Longitude (average)
# 0                "33"                "65"
# 1         "60.116667"              "19.9"
# 2                "41"                "20"
# 3                "28"                 "3"
# 4          "-14.3333"              "-170"
# ..                ...                 ...
# 95               "12"               "-15"
# 96               "11"               "-10"
# 97                "5"               "-59"
# 98               "19"          "-72.4167"
# 99            "-53.1"           "72.5167"
#
# [100 rows x 6 columns]
#
# === df_noc_iso3 ===
# Columns: ['NOC', 'ISO3']
# Number of rows: 234
# Data types:
#  NOC     object
# ISO3    object
# dtype: object
# Missing values:
#  NOC     0
# ISO3    0
# dtype: int64
# Sample data (first 100 rows):
#      NOC ISO3
# 0   AFG  AFG
# 1   AHO  ABW
# 2   ALB  ALB
# 3   ALG  DZA
# 4   AND  AND
# ..  ...  ...
# 95  IRI  IRN
# 96  IRL  IRL
# 97  IRQ  IRQ
# 98  ISL  ISL
# 99  ISR  ISR
#
# [100 rows x 2 columns]
#
# === df_noc_regions ===
# Columns: ['NOC', 'region', 'notes']
# Number of rows: 230
# Data types:
#  NOC       object
# region    object
# notes     object
# dtype: object
# Missing values:
#  NOC         0
# region      3
# notes     209
# dtype: int64
# Sample data (first 100 rows):
#      NOC              region                 notes
# 0   AFG         Afghanistan                   NaN
# 1   AHO             Curacao  Netherlands Antilles
# 2   ALB             Albania                   NaN
# 3   ALG             Algeria                   NaN
# 4   AND             Andorra                   NaN
# ..  ...                 ...                   ...
# 95  IRL             Ireland                   NaN
# 96  IRQ                Iraq                   NaN
# 97  ISL             Iceland                   NaN
# 98  ISR              Israel                   NaN
# 99  ISV  Virgin Islands, US        Virgin Islands
#
# [100 rows x 3 columns]

# %%
df_geo['ISO3'] = df_geo['Alpha-3 code'].astype(str).str.replace('"','').str.strip().str.upper()
df_geo['Country'] = df_geo['Country'].astype(str).str.replace('"','').str.strip()
df_geo['Latitude'] = df_geo['Latitude (average)'].astype(str).str.replace('"','').str.strip().astype(float)
df_geo['Longitude'] = df_geo['Longitude (average)'].astype(str).str.replace('"','').str.strip().astype(float)
df_geo = df_geo.drop_duplicates(subset='ISO3')
df_geo = df_geo[['ISO3','Country','Latitude','Longitude']]

df = df_athletes.merge(df_noc_iso3, how='left', on='NOC')

df = df.merge(df_noc_regions[['NOC','region']], how='left', on='NOC')
df.rename(columns={'region':'Region'}, inplace=True)

df = df.merge(df_geo, how='left', on='ISO3')

df['BMI'] = df['Weight'] / ((df['Height']/100) ** 2)

columns_order = ['ID','Name','Sex','Age','Height','Weight','BMI','Team','NOC',
                 'Region','ISO3','Country','Latitude','Longitude','Games','Year',
                 'Season','City','Sport','Event','Medal']

df = df[columns_order]

df = df.drop_duplicates()

print("Total rows:", df.shape[0])
print("Missing Country:", df['Country'].isna().sum())
print("Missing Latitude:", df['Latitude'].isna().sum())
print("Missing Longitude:", df['Longitude'].isna().sum())
print("Missing BMI:", df['BMI'].isna().sum())
# Out:
# Total rows: 269731
# Missing Country: 96
# Missing Latitude: 96
# Missing Longitude: 96
# Missing BMI: 62891

# %%
df_test = df.copy()
df_test.index = df_verify.index  
print(df_test.equals(df_verify))  # allt förutom index är korrekt
# Out:
# True

# %%
df.index = df_verify.index # lägger index av df_verify till df, detta kasnske borde fixas bättre

# %%
print("df_verify:")
print(f'Number of rows: {df_verify.shape[0]}')
print(f'Number of columns: {df_verify.shape[1]}')
display(df_verify.head())

print("\ndf:")
print(f'Number of rows: {df.shape[0]}')
print(f'Number of columns: {df.shape[1]}')
display(df.head())

(df.dtypes == df_verify.dtypes).all() and df.shape == df_verify.shape and df.equals(df_verify) # korrekt om den är True
# Out:
# df_verify:
# Number of rows: 269731
# Number of columns: 21
#    ID                      Name Sex   Age  Height  Weight        BMI  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  24.691358
# 1   2                  A Lamusi   M  23.0   170.0    60.0  20.761246
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN        NaN
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN        NaN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  23.959094
#
#              Team  NOC       Region ISO3      Country  Latitude  Longitude  \
# 0           China  CHN        China  CHN        China      35.0     105.00
# 1           China  CHN        China  CHN        China      35.0     105.00
# 2         Denmark  DEN      Denmark  DNK      Denmark      56.0      10.00
# 3  Denmark/Sweden  DEN      Denmark  DNK      Denmark      56.0      10.00
# 4     Netherlands  NED  Netherlands  NLD  Netherlands      52.5       5.75
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN
# df:
# Number of rows: 269731
# Number of columns: 21
#    ID                      Name Sex   Age  Height  Weight        BMI  \
# 0   1                 A Dijiang   M  24.0   180.0    80.0  24.691358
# 1   2                  A Lamusi   M  23.0   170.0    60.0  20.761246
# 2   3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN        NaN
# 3   4      Edgar Lindenau Aabye   M  34.0     NaN     NaN        NaN
# 4   5  Christine Jacoba Aaftink   F  21.0   185.0    82.0  23.959094
#
#              Team  NOC       Region ISO3      Country  Latitude  Longitude  \
# 0           China  CHN        China  CHN        China      35.0     105.00
# 1           China  CHN        China  CHN        China      35.0     105.00
# 2         Denmark  DEN      Denmark  DNK      Denmark      56.0      10.00
# 3  Denmark/Sweden  DEN      Denmark  DNK      Denmark      56.0      10.00
# 4     Netherlands  NED  Netherlands  NLD  Netherlands      52.5       5.75
#
#          Games  Year  Season       City          Sport  \
# 0  1992 Summer  1992  Summer  Barcelona     Basketball
# 1  2012 Summer  2012  Summer     London           Judo
# 2  1920 Summer  1920  Summer  Antwerpen       Football
# 3  1900 Summer  1900  Summer      Paris     Tug-Of-War
# 4  1988 Winter  1988  Winter    Calgary  Speed Skating
#
#                               Event Medal
# 0       Basketball Men's Basketball   NaN
# 1      Judo Men's Extra-Lightweight   NaN
# 2           Football Men's Football   NaN
# 3       Tug-Of-War Men's Tug-Of-War  Gold
# 4  Speed Skating Women's 500 metres   NaN
# True

# %% [markdown]
# ---
# ## Task 1.2 Feature Measurement Scales
#
# Characterize each feature (column) using [Stevens’ four levels of measurement](https://en.wikipedia.org/wiki/Level_of_measurement) below:
# - Nominal
# - Ordinal
# - Interval
# - Ratio

# %%
# TODO: Write your answer here.

# ------------------------------------------------------------------------------------------------------------------
# Feature   | Measurement Scale (mark 1 with an 'x') | Rationale 
# (Column)  | Nominal : Ordinal : Interval : Ratio   | (Why did you choose that measurement scale for that feature?)
# ------------------------------------------------------------------------------------------------------------------
# ID        |    x     :         :          :         | ID is nominal since the order in which they appear is not relevant, it just tells us who is who
# Name      |    x    :         :          :          | Name is a string and not a number, just used to specify who is who like ID
# Sex       |    x    :         :          :          | We cannot perform any comparisons like greater or less, but we can check frequency of different sexes
# Age       |        :         :          :    x      | Age is Ratio because it has a true zero, which means no age at all, but temp for instance which is a interval, where zero is not "true" zero
# Height    |         :         :          :   x      | The same as age
# Weight    |         :         :          :   x      | The same as age
# BMI       |         :         :          :   x      | Zero means no body mass, which then means it has a true zero
# Team      |    x     :         :          :         | Team is used to divide them into categories
# NOC       |    x     :         :          :         | Same as team
# Region    |    x     :         :          :         | Used to divide them into place of origin
# ISO3      |    x     :         :          :         | Same as region
# Country   |    x     :         :          :         | same as region
# Latitude  |         :         :    x      :         | Can be below zero, which means it does not have a true zero. Zero is a specific point.
# Longitude |         :         :    x      :         | same as longitude
# Games     |    x     :         :          :         | Altough the year is used, which could be a interval, in this case it just simply categorizes the competitors in the different games
# Year      |         :         :    x      :         | This one is a interval since you cannot add or subtract the years but it has a fixed gap
# Season    |    x     :         :          :         | Used to determine what type of olympic games it is, and is therefore nominal
# City      |    x     :         :          :         | Cannot be used to perform comparisons like greater or smaller, we can just group them together based on name.
# Sport     |    x     :         :          :         | Order is not relevant, but states what they competed in, and is therefore nominal
# Event     |    x     :         :          :         | same as sports
# Medal     |         :    x     :          :         | This is ordinal since the order matters and has different meanings depending on what they have

# %% [markdown]
# ---
# # Task 2: Summary Statistics
# ---

# %% [markdown]
# Use the [Numpy Guide](https://numpy.org/learn) and [Pandas Guide](https://pandas.pydata.org/docs/user_guide/index.html) to consult the documentation and view code examples, if needed.
#
# ## Task 2.1 Missing Values
#
# How many missing values are there per column?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > ID                0
# > Name              0
# > Sex               0
# > Age            9315
# > Height        58814
# > Weight        61527
# > BMI           62891
# > Team              0
# > NOC               0
# > Region          370
# > ISO3              0
# > Country          96
# > Latitude         96
# > Longitude        96
# > Games             0
# > Year              0
# > Season            0
# > City              0
# > Sport             0
# > Event             0
# > Medal        229959
# > ```
#
# </details>

# %%
missing_counts = df.isna().sum()

print(missing_counts)
# Out:
# ID                0
# Name              0
# Sex               0
# Age            9315
# Height        58814
# Weight        61527
# BMI           62891
# Team              0
# NOC               0
# Region          370
# ISO3              0
# Country          96
# Latitude         96
# Longitude        96
# Games             0
# Year              0
# Season            0
# City              0
# Sport             0
# Event             0
# Medal        229959
# dtype: int64

# %% [markdown]
# Given your result from above, would it be possible to impute (replace) the missing values for the affected features (columns)?
# - Don't drop any rows or columns with missing values, or impute (replace) any missing values.
# - You only have to answer the question stated above.

# %%
# It would be possible to replace the age with the median age for the sport and gender, but it wouldnt make for a reliable dataset. I would not impute any values.

# %% [markdown]
# ---
# ## Task 2.2 Unique Values
#
# How many unique values does the `Region` feature (column) contain?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > 206
# > ```
#
# </details>

# %%
print(df['Region'].nunique())
#gets one less than correct answer??
# Out:
# 205

# %% [markdown]
# ---
# ## Task 2.3 Value Counts
#
# How many instances of each value are there in the `Medal` feature (column)?
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > Gold      13369
# > Bronze    13295
# > Silver    13108
# > ```
#
# </details>

# %%
# TODO: Write your code here to count the number of Gold, Silver, and Bronze medals.
print(df["Medal"].value_counts())
# Out:
# Medal
# Gold      13369
# Bronze    13295
# Silver    13108
# Name: count, dtype: int64

# %% [markdown]
# ---
# ## Task 2.4 Central Tendency and Spread
#
# How are the values in the numeric features (columns) distributed?
# - The numeric features (columns) are `ID`, `Age`, `Height`, `Weight`, `BMI`, `Latitude`, `Longitude`, and `Year`.
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# >                  ID             Age          Height          Weight             BMI        Latitude       Longitude            Year
# > count 269731.000000   260416.000000   210917.000000   208204.000000   206840.000000   269635.000000   269635.000000   269731.000000
# > mean   68264.949591       25.454776      175.338953       70.701778       22.784470       38.357629       14.336823     1978.623073
# > std    39026.253843        6.163869       10.518507       14.349027        2.912083       23.797926       64.719581       29.752055
# > min        1.000000       10.000000      127.000000       25.000000        8.360954      -41.000000     -176.200000     1896.000000
# > 25%    34655.500000       21.000000      168.000000       60.000000       20.957171       36.000000       -2.000000     1960.000000
# > 50%    68233.000000       24.000000      175.000000       70.000000       22.530864       46.000000       12.833300     1988.000000
# > 75%   102111.000000       28.000000      183.000000       79.000000       24.212293       52.500000       26.000000     2002.000000
# > max   135571.000000       97.000000      226.000000      214.000000       63.901580       65.000000      178.000000     2016.000000
# > ```
#
# </details>

# %%
numeric_cols = ["ID", "Age", "Height", "Weight", "BMI", "Latitude", "Longitude", "Year"]

print(df[numeric_cols].describe())
# Out:
#                   ID            Age         Height         Weight  \
# count  269731.000000  260416.000000  210917.000000  208204.000000
# mean    68264.949591      25.454776     175.338953      70.701778
# std     39026.253843       6.163869      10.518507      14.349027
# min         1.000000      10.000000     127.000000      25.000000
# 25%     34655.500000      21.000000     168.000000      60.000000
# 50%     68233.000000      24.000000     175.000000      70.000000
# 75%    102111.000000      28.000000     183.000000      79.000000
# max    135571.000000      97.000000     226.000000     214.000000
#
#                  BMI       Latitude      Longitude           Year
# count  206840.000000  269635.000000  269635.000000  269731.000000
# mean       22.784470      38.357629      14.336823    1978.623073
# std         2.912083      23.797926      64.719581      29.752055
# min         8.360954     -41.000000    -176.200000    1896.000000
# 25%        20.957171      36.000000      -2.000000    1960.000000
# 50%        22.530864      46.000000      12.833300    1988.000000
# 75%        24.212293      52.500000      26.000000    2002.000000
# max        63.901580      65.000000     178.000000    2016.000000

# %% [markdown]
# ---
# ## Task 2.5 Outliers
#
# How many outliers are there in the `Age` feature (column)?
# - Numerous methods exist to detect [Outliers](https://en.wikipedia.org/wiki/Outlier) mathematically.
# - One such method uses the [1.5 x IQR Rule](https://www.khanacademy.org/math/statistics-probability/summarizing-quantitative-data/box-whisker-plots/a/identifying-outliers-iqr-rule), where **IQR** is the **Inter Quartile Range**.
#   - The first Quartile (`Q1`) is the same as the `25th Percentile`.
#   - The second Quartile (`Q2`) is the same as the `50th Percentile`.
#   - The third Quartile (`Q3`) is the same as the `75th Percentile`.
#   - The fourth Quartile (`Q4`) is the same as the `100th Percentile`.
#   - The Inter Quartile Range (`IQR`) is defined as: `IQR = Q3 - Q1`.
#   - The `1.5 x IQR Rule` states that:
#     - Any data point that lies below `Q1 - 1.5 * IQR` is considered an outlier.
#     - Any data point that lies above `Q3 + 1.5 * IQR` is considered an outlier.
#
# Pandas `Series` have a method `quantile()` to calculate Quantiles.
# - `Q1 = quantile(0.25)`
# - `Q3 = quantile(0.75)`
#
# Note on **Quantiles** vs **Quartiles** vs **Percentiles**
# - A **Quantile** is a general partition (subdivision) of values, e.g. a 0.05, 0.10, 0.25, or 0.76 fraction of the values.
# - A **Quartile** is also a type of **Quantile**, but **Quartiles** partition values into four disjoint subsets 1st, 2nd, 3rd and 4th quarter of the values.
# - A **Percentile** is also a type of **Quantile**, but **Percentiles** partition values between 0% to 100% of the values.
#
# <details>
# <summary>Compare (verify) your solution to the correct answer (click to expand)</summary>
#
# > ```python
# > 9421
# > ```
#
# </details>

# %%
# TODO: Write your code here to calculate and print out the number of outliers in the `Age` feature (column).
Q1 = df["Age"].quantile(0.25)
Q3 = df["Age"].quantile(0.75)
IQR = Q3 - Q1

lower = Q1-1.5*IQR
higher = Q3+1.5*IQR

outliers = df[(df["Age"]< lower)+(df["Age"]>higher)]
print(len(outliers))
# Out:
# 9421

# %% [markdown]
# ---
# # Task 3: Distribution Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 3.1 Visualize the Distribution of Male and Female Athletes
#
# Create a visualization showing the number of Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_1.png" width=600></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of Male and Female athletes.

sex_counts = df["Sex"].value_counts()

sex_counts.plot(kind="bar", color=["skyblue", "lightpink"])
plt.grid(axis="y")
plt.gca().set_axisbelow(True)
plt.title("Number of Male and Female Athletes")
plt.ylabel("Count")
plt.xlabel("Sex")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Task 3.2 Visualize the Distribution of Athletes' Age
#
# Create a visualization showing the athlete Age distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_2.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of athlete Age.
import seaborn as sns

sns.histplot(data=df, x="Age", bins=40, edgecolor="white", kde=True)

plt.title("Age Distribution of Athletes")
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.grid(axis="y", linestyle="--", alpha=0.7)
plt.show()

# %% [markdown]
# ---
# ## Task 3.3 Visualize the Distribution of Athletes' Height
#
# Create a visualization showing the athlete Height distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_3.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the distribution of athlete Height.
sns.histplot(data=df, x="Height", bins=40, edgecolor="white", kde=True)

plt.title("Height Distribution of Athletes")
plt.xlabel("Height")
plt.ylabel("Frequency")
plt.grid(alpha=0.7)
plt.show()

# %% [markdown]
# ---
# ## Task 3.4 Visualize the Distribution of Athletes' Weight
#
# Create a visualization showing the athlete Weight distribution (counts, frequencies).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_4.png" width=1200></img>
#
# </details>

# %%
sns.histplot(data=df, x="Weight", bins=40, edgecolor="white", kde=True)

plt.title("Weight Distribution of Athletes")
plt.xlabel("Weight")
plt.ylabel("Frequency")
plt.grid(alpha=0.7)
plt.show()

# %% [markdown]
# ---
# ## Task 3.5 Visualize the Distribution in Height of Male and Female Athletes
#
# Create a visualization showing the height distribution (counts, frequencies) of Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_5.png" width=600></img>
#
# </details>

# %%
import matplotlib.pyplot as plt
import numpy as np

# Heights
women_heights = df.loc[df["Sex"] == "F", "Height"]
male_heights = df.loc[df["Sex"] == "M", "Height"]

# Bins
bins = np.linspace(min(df["Height"].dropna()), max(df["Height"].dropna()), 30)
bin_centers = (bins[:-1] + bins[1:])/2 

# Histogram counts
women_counts, _ = np.histogram(women_heights, bins=bins)
male_counts, _ = np.histogram(male_heights, bins=bins)

# Convert to percentages
women_freq = women_counts / women_counts.sum()
male_freq = male_counts / male_counts.sum()

# Plot
plt.plot(bin_centers, women_freq, label="Women", color="pink")
plt.plot(bin_centers, male_freq, label="Men", color="skyblue")
plt.title("Height Distribution of Athletes")
plt.xlabel("Height (cm)")
plt.ylabel("Frequency")
plt.grid(alpha=0.7)
plt.legend()
plt.show()

# %% [markdown]
# ---
# ## Task 3.6 Visualize the Height per Type of Medal for Male and Female Athletes
#
# Create a visualization showing the athelete height per type of medal (gold, silver, bronze) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_6.png" width=600></img>
#
# </details>

# %%
# Filter only athletes with medals
medal_df = df[df["Medal"].notna()]

# Define medal types and sexes
medals = ["Gold", "Silver", "Bronze"]
sexes = ["M", "F"]
colors = {"M": "skyblue", "F": "pink"}

# Width of each bar
bar_width = 0.35

# x positions for each medal
x = np.arange(len(medals))

# Compute average heights
avg_heights_male = [medal_df[(medal_df["Medal"]==medal) & (medal_df["Sex"]=="M")]["Height"].mean() for medal in medals]
avg_heights_female = [medal_df[(medal_df["Medal"]==medal) & (medal_df["Sex"]=="F")]["Height"].mean() for medal in medals]

# Plot bars
plt.figure(figsize=(8,6))
plt.bar(x - bar_width/2, avg_heights_male, width=bar_width, color=colors["M"], label="Male")
plt.bar(x + bar_width/2, avg_heights_female, width=bar_width, color=colors["F"], label="Female")

# Labels and legend
plt.xticks(x, medals)
plt.xlabel("Medal")
plt.ylabel("Average Height (cm)")
plt.title("Average Athlete Height by Medal and Sex")
plt.legend(loc='lower left')
plt.grid(axis="y", alpha=0.5)
plt.show()

# %% [markdown]
# ---
# ## Task 3.7 Visualize the Weight per Type of Medal for Male and Female Athletes
#
# Create a visualization showing the athelete weight per type of medal (gold, silver, bronze) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_7.png" width=600></img>
#
# </details>

# %%
# Filter only athletes with medals
medal_df = df[df["Medal"].notna()]

# Define medal types and sexes
medals = ["Gold", "Silver", "Bronze"]
sexes = ["M", "F"]
colors = {"M": "skyblue", "F": "pink"}

# Width of each bar
bar_width = 0.35

# x positions for each medal
x = np.arange(len(medals))

# Compute average heights
avg_weight_male = [medal_df[(medal_df["Medal"]==medal) & (medal_df["Sex"]=="M")]["Weight"].mean() for medal in medals]
avg_weight_female = [medal_df[(medal_df["Medal"]==medal) & (medal_df["Sex"]=="F")]["Weight"].mean() for medal in medals]

# Plot bars
plt.figure(figsize=(8,6))
plt.bar(x - bar_width/2, avg_weight_male, width=bar_width, color=colors["M"], label="Male")
plt.bar(x + bar_width/2, avg_weight_female, width=bar_width, color=colors["F"], label="Female")

# Labels and legend
plt.xticks(x, medals)
plt.xlabel("Medal")
plt.ylabel("Average Weight (kg)")
plt.title("Average Athlete Weight by Medal and Sex")
plt.legend(loc='lower left')
plt.grid(axis="y", alpha=0.5)
plt.show()

# %% [markdown]
# ---
# ## Task 3.8 Visualize Height per Type of Medal for Male and Female Athletes Faceted by Season
#
# Create a visualization showing the athelete height per type of medal (gold, silver, bronze) for Male and Female athletes, faceted (grouped) by Season (Summer, Winter).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_8.png" width=1100></img>
#
# </details>

# %%
medal_df = df[df["Medal"].notna()]

# Parameters
medals = ["Gold", "Silver", "Bronze"]
sexes = ["M", "F"]
colors = {"M": "skyblue", "F": "pink"}
bar_width = 0.2

fig, axes = plt.subplots(1, 2, figsize=(12,6), sharey=True)

for ax, season in zip(axes, ["Summer", "Winter"]):
    x = np.arange(len(medals))
    
    for k, medal in enumerate(medals):
        for sex in sexes:
            heights = medal_df[(medal_df["Medal"]==medal) & 
                               (medal_df["Sex"]==sex) & 
                               (medal_df["Season"]==season)]["Height"]
            
            x_scatter = x[k] + (np.random.rand(len(heights)) - 0.5) * bar_width
            ax.scatter(x_scatter, heights, color=colors[sex], label=sex if (k==0 and ax==axes[0]) else "")

    ax.set_xticks(x)
    ax.set_xticklabels(medals)
    ax.set_xlabel("Medal")
    ax.set_title(f"{season} Games")
    ax.grid(axis="y", alpha=0.5)

# Shared y-label
axes[0].set_ylabel("Height (cm)")

# Legend
legend_elements = [Patch(facecolor=colors[sex], label="Male" if sex=="M" else "Female") for sex in sexes]
axes[1].legend(handles=legend_elements, title="Sex", loc='lower left')

plt.suptitle("Athlete Heights by Medal, Sex, and Season")
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[59], line 33
#      30 axes[0].set_ylabel("Height (cm)")
#      32 # Legend
# ---> 33 legend_elements = [Patch(facecolor=colors[sex], label="Male" if sex=="M" else "Female") for sex in sexes]
#      34 axes[1].legend(handles=legend_elements, title="Sex", loc='lower left')
#      36 plt.suptitle("Athlete Heights by Medal, Sex, and Season")
#
# NameError: name 'Patch' is not defined

# %% [markdown]
# ---
# ## Task 3.9 Visualize the Average Age per Sport
#
# Create a visualization showing the average athelete Age per Sport (Curling, Triathlon, Handball, Tennis, Gymastics, Football, etc.).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_9.png" width=1500></img>
#
# </details>

# %%
# Calculate average age per sport
avg_age_per_sport = df.groupby("Sport")["Age"].mean().sort_values()

# Generate a gradient of colors across the bars
n_bars = len(avg_age_per_sport)
colors = plt.cm.bwr(np.linspace(1, 0, n_bars))  # blue → red gradient

# Horizontal bar chart
plt.figure(figsize=(12,12))
plt.barh(avg_age_per_sport.index, avg_age_per_sport.values, color=colors)
plt.xlabel("Average Age")
plt.ylabel("Sport")
plt.title("Average Athlete Age per Sport (Blue → Red Gradient)")
plt.grid(axis='x', alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Task 3.10 Visualize the Top 10 Countries (Regions) with Most Total Medals
#
# Create a visualization showing the number of total medals (gold, silver and bronze) awarded per country (region), for the top ten countries (regions) with most medals.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_10.png" width=1000></img>
#
# </details>

# %%
medal_df = df[df["Medal"].notna()]

medals_per_region = medal_df.groupby("Region")["Medal"].count().sort_values(ascending=False)

top_10_regions = medals_per_region.head(10)

plt.figure(figsize=(12, 8))
colors = plt.cm.Set3(np.linspace(0, 1, len(top_10_regions)))
bars = plt.bar(range(len(top_10_regions)), top_10_regions.values, color=colors)

plt.xticks(range(len(top_10_regions)), top_10_regions.index, rotation=45, ha='right')
plt.ylabel("Total Number of Medals")
plt.xlabel("Country/Region")
plt.title("Top 10 Countries by Total Medal Count")
plt.grid(axis="y", alpha=0.5)

for i, v in enumerate(top_10_regions.values):
    plt.text(i, v + 20, str(v), ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Task 3.11 Visualize the Top 10 Atheletes by Total Awarded Medals
#
# Create a visualization showing the top ten athletes by total number of awarded medals (gold, silver and bronze).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_11.png" width=1000></img>
#
# </details>

# %%
medal_df = df[df["Medal"].notna()]

medals_per_athlete = medal_df.groupby("Name")["Medal"].count().sort_values(ascending=False)

top_10_athletes = medals_per_athlete.head(10)

plt.figure(figsize=(12, 8))
colors = plt.cm.Set3(np.linspace(0, 1, len(top_10_athletes)))
bars = plt.barh(range(len(top_10_athletes)), top_10_athletes.values, color=colors)

plt.yticks(range(len(top_10_athletes)), top_10_athletes.index)
plt.xlabel("Total Number of Medals")
plt.ylabel("Athlete Name")
plt.title("Top 10 Athletes by Total Medal Count")
plt.gca().invert_yaxis()  # To have the highest on top
plt.grid(axis="x", alpha=0.5)

for i, v in enumerate(top_10_athletes.values):
    plt.text(v + 0.5, i, str(v), va='center', ha='left')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## Task 3.12 Visualize the Age, Height and Weight Distribution per Type of Medal
#
# Create three `subplots`, side-by-side, for comparison purposes:
# 1. Create a visualization using a `boxplot` showing the Age distribution per medal type (gold, silver and bronze).
# 2. Create a visualization using a `boxplot` showing the Height distribution per medal type (gold, silver and bronze).
# 3. Create a visualization using a `boxplot` showing the Weight distribution per medal type (gold, silver and bronze).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_3_12.png" width=1500></img>
#
# </details>

# %%
medal_df = df[df["Medal"].notna()]

# Create three subplots side by side
fig, axes = plt.subplots(1, 3, figsize=(15, 6))

medal_colors = {"Gold": "gold", "Silver": "silver", "Bronze": "#CD7F32"}

sns.boxplot(data=medal_df, x="Medal", y="Age", ax=axes[0], palette=medal_colors)
axes[0].set_title("Age Distribution by Medal Type")
axes[0].set_xlabel("Medal")
axes[0].set_ylabel("Age")
axes[0].grid(axis="y", alpha=0.5)

# Height distribution per medal type
sns.boxplot(data=medal_df, x="Medal", y="Height", ax=axes[1], palette=medal_colors)
axes[1].set_title("Height Distribution by Medal Type")
axes[1].set_xlabel("Medal")
axes[1].set_ylabel("Height (cm)")
axes[1].grid(axis="y", alpha=0.5)

# Weight distribution per medal type
sns.boxplot(data=medal_df, x="Medal", y="Weight", ax=axes[2], palette=medal_colors)
axes[2].set_title("Weight Distribution by Medal Type")
axes[2].set_xlabel("Medal")
axes[2].set_ylabel("Weight (kg)")
axes[2].grid(axis="y", alpha=0.5)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Oscar\AppData\Local\Temp\ipykernel_24444\3867399186.py:8: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=medal_df, x="Medal", y="Age", ax=axes[0], palette=medal_colors)
# C:\Users\Oscar\AppData\Local\Temp\ipykernel_24444\3867399186.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=medal_df, x="Medal", y="Height", ax=axes[1], palette=medal_colors)
# C:\Users\Oscar\AppData\Local\Temp\ipykernel_24444\3867399186.py:22: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=medal_df, x="Medal", y="Weight", ax=axes[2], palette=medal_colors)

# %% [markdown]
# ---
# ## Task 3.13 Interpret a Box Plot's Visual Elements
#
# A Box Plot (a.k.a. Box-and-Whiskers Plot) resembles a "Box" with "Whiskers" extending from the "Box" and usually some points below and above the "Whiskers".
#
# What information is shown in a  Box plot?
#
# - What does the "Box" represent?
# - What does the "line" inside the "Box" represent?
# - What does "Box's" lower "line" (bottom of the "Box") represent?
# - What does "Box's" upper "line" (top of the "Box") represent?
# - What does the lower "whisker" represent?
# - What does the upper "whisker" represent?
# - What do the data points below the lower "whisker" and above the upper "whisker" represent?

# %%
# TODO: Write your answer here.

# The "Box" represents: The values between the first quartile and the third quartile.
# The "line" inside the "Box" represents: The median value.
# THe "Box's" lower "line" (bottom of the "Box") represents: The first quartile.
# The "Box's" upper "line" (top of the "Box") represents: The third quartile. 
# The lower "whisker" represents: Values measured out with 1.5 IQR below the first quartile.
# The upper "whisker" represents: Values measured out with 1.5 IQR above the third quartile.
# The data points below the lower "whisker" and above the upper "whisker" represent: outliers.

# %% [markdown]
# ---
# # Task 4: Trend Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 4.1 Visualize Body Mass Index (BMI) Over Time
#
# Create a visualization showing the Body Mass Index (BMI) over time (years) for Male and Female athletes.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_4_1.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize Body Mass Index (BMI) over time (years) per Sex (Male, Female).
plt.figure(figsize=(12,6))
sns.lineplot(
    data=df,
    x="Year",
    y="BMI",
    hue="Sex",
    errorbar=('ci', 95),
    estimator="mean",  
    palette={"M": "blue", "F": "red"}
)

plt.title("BMI Over Time")
plt.xlabel("Year")
plt.ylabel("BMI")
plt.legend(title="Sex")
plt.grid()
plt.show()

# %% [markdown]
# ---
# ## Task 4.2 Visualize Gender (Sex) Participation Over Time
#
# Create a visualization showing the number of Male and Female athletes over time (years).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_4_2.png" width=1200></img>
#
# </details>

# %%
# TODO: Write your code here to visualize gender participation over time.
df_participation = (
    df.groupby(['Year', 'Sex'])['ID']
    .count()
    .reset_index(name='Number of Athletes')
)

plt.figure(figsize=(14,8))
sns.lineplot(
    data=df_participation,
    x="Year",
    y="Number of Athletes",
    hue="Sex",
    palette={"M": "blue", "F": "red"}
)

plt.title("Gender Participation Over Time")
plt.xlabel("Year")
plt.ylabel("Number of Athletes")
plt.legend(title="Sex")
plt.grid()
plt.show()

# %% [markdown]
# ---
# # Task 5: Correlation Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 5.1 Visualize Pairwise Correlations of Athlete's Age, Height and Weight per Sex with a `pairplot`
#
# Create a `pairplot` showing the pariwise correlations of athlete Age, Height and Weight, color-coded by Sex (Male, Female).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_1.png" width=800></img>
#
# </details>

# %%
# TODO: Write your code here to visualize pairwise correlations of athlete Age, Height and Weight per Sex using a pair plot.

# Create pairplot for Age, Height, Weight, colored by Sex
pair_plot = sns.pairplot(df, vars=["Age", "Height", "Weight"], hue="Sex")

# Add a super title
pair_plot.fig.suptitle("Pairwise Relationships: Age, Height, Weight", y=1.02)

plt.show()

# %% [markdown]
# ---
# ## Task 5.2 Visualize Pairwise Correlations of the Numeric Features with a `heatmap`
#
# Create a `heatmap` showing the pariwise correlations of the numeric features (columns).
# - The numeric features (columns) are `ID`, `Age`, `Height`, `Weight`, `BMI`, `Latitude`, `Longitude`, and `Year`.
# - Hint: a Pandas DataFrame has a `corr()` method.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_2.png" width=700></img>
#
# </details>

# %%
# TODO: Write your code here to visualize pairwise correlations of the numeric featues (columns) using a heat map.

numeric_features = ["ID", "Age", "Height", "Weight", "BMI", "Latitude", "Longitude", "Year"]
corr_matrix = df[numeric_features].corr()

#vet inte vad det är för colormap
plt.figure(figsize=(10, 6))
sns.heatmap(corr_matrix, annot=True, cmap="RdBu", fmt=".2f")

plt.title("Pairwise Correlations of Numeric Features")
plt.show()

# %% [markdown]
# ---
# ## Task 5.3 Visualize Atheltes' Weight versus Height per Sex with a `lineplot`
#
# Create a visualization showing the athelete Weight versus Height per Sex (Male, Female) using a `lineplot`.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_3.png" width=1400></img>
#
# </details>

# %%
# TODO: Write your code here to visualize athlete Weight versus Height per Sex (Male, Female) using a line plot.
df_male = df[df["Sex"] == "M"]
df_female = df[df["Sex"] == "F"]
sns.lineplot(x= df_male["Height"],y=(df_male["Weight"]), color="blue", label="Male")
sns.lineplot(x=(df_female["Height"]),y=(df_female["Weight"]), color="red", label="Female")
plt.grid()
plt.legend()

# %% [markdown]
# ---
# ## Task 5.4 Visualize Atheltes' Weight versus Height per Sex with a `scatterplot`
#
# Create a visualization showing the athelete Weight versus Height per Sex (Male, Female) using a `scatterplot`.
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_5_4.png" width=700></img>
#
# </details>

# %%
# TODO: Write your code here to visualize athlete Weight versus Height per Sex (Male, Female) using a scatter plot.
df_male = df[df["Sex"] == "M"]
df_female = df[df["Sex"] == "F"]
plt.scatter((df_male["Height"]),(df_male["Weight"]), color="blue", label="Male", edgecolors="white")
plt.scatter((df_female["Height"]),(df_female["Weight"]), color="red", label="Female", edgecolors= "white")
plt.legend()

# %% [markdown]
# ---
# # Task 6: Map Visualizations
# ---

# %% [markdown]
# Use the [Matplotlib Gallery](https://matplotlib.org/stable/gallery/index.html) and [Seaborn Gallery](https://seaborn.pydata.org/examples/index.html) to consult the documentation and view code examples, if needed.
# - You can use either Matplotlib or Seaborn (or both) to create your plots.
# - When creating your plots, consider the **Semiology of graphical symbols**, i.e. the eight ways for graphical objects to encode information:
#   - Position
#   - Shape
#   - Size
#   - Brightness
#   - Color
#   - Orientation
#   - Texture
#   - Motion
# - Also consider the **expressiveness** and **effectiveness** of your visualizations, i.e.:
#   - Make sure you are expressing (mapping) the underlying data with your visual elements appropriately.
#   - Make sure you are not including too much information in your visualizations to make them more intuitive and more comprehensible to the user.
# - Reflect, mentally, on your visualizations.
#   - Are you using an appropriate plot?
#     - This might also include subplots.
#   - Are you using position, shape, size, color, etc. (semiology) appropriately?
#     - Are you using an appropriate color scale (color map)?
#     - Have you considered appropriate colors for color blindness?
#   - Is all the necessary (but not too much) information included in the visualization?
#     - This might also include figure titles, axis labels, legends, colorbars, etc.
#   - Is your mapping from data to visual elements appropriate?
#     - Does your visualization give a correct, or false, representation of the underlying data?
#   - When you look at your visualizations, how intuitive and comprehensible are they?
#     - Will a user quickly understand what the visualization is about?
#     - Will a user quickly discover important patterns?
#     - Will the user be able to quickly analyze the information?
# - Use *data mangling* to put the data into an appropriate format before creating a visualization.
#   - You can use a DataFrame's `groupby()` method (with or without aggrations), slicing, etc. before creating a visualization (it depends on what you are visualizing).
#
# **Recommended reading (not mandatory)**
#
# Franconeri, Padilla, Shah, Zacks & Hullman. (2021). The Science of Visual Data Communication: What Works, Psychological Science in the Public Interest, 22(3), 110-161. DOI: 10.1177/15291006211051956.
# [https://journals.sagepub.com/doi/10.1177/15291006211051956](https://journals.sagepub.com/doi/10.1177/15291006211051956)

# %% [markdown]
# ---
# ## Task 6.1 Visualize Number of Medals on a Map for the Nordic Countries
#
# Create a visualization showing the number of Medals awarded for the nordic countries (Sweden, Norway, Denmark, Finland).
#
# <details>
# <summary>View a similar (not necessarily identical) visualization so you know what you are aiming for (click to expand)</summary>
#
# > <img src="figures/task_6_1.png" width=800></img>
#
# </details>

# %%
# TODO: Write your code here to visualize the number of Medals on a Map for the nordic countries.
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import matplotlib.colors as mcolors
from mpl_toolkits.basemap import Basemap


nordic_iso3 = ['SWE', 'NOR', 'DNK', 'FIN'] 
medal_df = df[df['Medal'].notna() & df['ISO3'].isin(nordic_iso3)]
medal_counts = (
    medal_df.groupby(['Country', 'ISO3', 'Latitude', 'Longitude'], as_index=False)['Medal']
            .count()
)

# Karta
fig, ax = plt.subplots(figsize=(8, 8))
m = Basemap(
    projection='merc', llcrnrlat=54, urcrnrlat=72, llcrnrlon=5, urcrnrlon=32,
    resolution='i', ax=ax
)
m.drawcoastlines(); m.drawcountries()
m.drawmapboundary(fill_color='lightblue')
m.fillcontinents(color='beige', lake_color='lightblue')

# Uppdelad färgskala i 5 delar
vmin = medal_counts['Medal'].min()
vmax = medal_counts['Medal'].max()
bins = [600, 800, 1000, 1200, 1400, vmax]
if vmin < bins[0]:
    bins = [vmin] + bins

cmap = plt.get_cmap('cividis', len(bins) - 1)   
norm = mcolors.BoundaryNorm(bins, cmap.N)

# Färg bubblar och text
for _, row in medal_counts.iterrows():
    x, y = m(row['Longitude'], row['Latitude'])
    color = cmap(norm(row['Medal']))
    m.scatter(x, y, s=row['Medal']*2, color=color, alpha=0.8, edgecolor='black', zorder=5)
    ax.text(x, y, row['ISO3'], fontsize=11, ha='center', va='center', weight='bold', zorder=15)

# Färgskala
sm = cm.ScalarMappable(norm=norm, cmap=cmap)
sm.set_array([])
cbar = fig.colorbar(sm, ax=ax, fraction=0.035, pad=0.02,
                    ticks=[600, 800, 1000, 1200, 1400])
cbar.set_label('Medals', rotation=90, labelpad=12)

# tabellen för att se antal medaljer
display(medal_counts[['Country', 'Medal']].sort_values('Medal', ascending=False))
# Out:
#    Country  Medal
# 3   Sweden   1536
# 2   Norway   1033
# 1  Finland    900
# 0  Denmark    597

# %% [markdown]
# ---
# # Task 7: Submission
# ---

# %% [markdown]
# ## Task 7.1 Verify the Integrity of your Notebook

# %% [markdown]
# The final task is to verify your Notebook before submitting it, and of course submitting it via Canvas.
#
# - Have you included any additional packages you might have used in your Notebook under [Python Packages](#python-packages)?
# - Have you imported any additional modules you might have used in your Notebook under [Python Modules](#python-modules)?
# - Is your Pandas DataFrame (`df`) identical to the DataFrame `df_verify` under [Task 1.1 Data Loading, Data Fusion, Data Cleaning, and Feature Engineering](#task-11-data-loading-data-fusion-data-cleaning-and-feature-engineering)?
# - Have you completed all tasks (`TODOs`) in the Notebook?
# - Have you reflected over your visualizations (semiology, expressiveness, effectiveness, etc.)?
#
# When you are done:
# - Click the `Restart` button at the top of the Notebook to restart the Jupyter Notebook kernel.
# - Then click the `Run All` button at the top of the Notebook, to execute all Notebook cells.
#   - Check that all Notebook cells executed successfully with the desired results.

# %% [markdown]
# ---
# ## Task 7.2 Submit the Assignment

# %% [markdown]
# - Save you Notebook and submit it via [Canvas](https://hb.instructure.com/courses/10009/assignments/40722) before the deadline (only submit one `.ipynb` file).
